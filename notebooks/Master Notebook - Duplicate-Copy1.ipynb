# %% [markdown]
# <div class='alert' style='background-color: #1c1a1e; color: #f5f4f0; padding:16px 26px; border-radius:20px; font-size:40px;'><B>Project Name</b> - First Notebook </div>
# <div style='margin:0px 26px; color:#1c1a1e; font-size:16px;'>
# <ol>
# <li><B>Notebook Documentation</B>: Documenting a Jupyter Notebook is crucial for ensuring that the analysis it contains is understandable and reproducible, not only by others but also by your future self.
# Best practices in documentation start with a clear, informative introduction: what the notebook aims to achieve, the dataset being used, and any prerequisite knowledge or context needed to follow the analysis.
# Each cell, especially those containing key computations or decisions, should be accompanied by Markdown cells explaining the rationale behind the code, any assumptions made, and a summary of the results. Inline comments within the code cells can clarify complex lines of code or non-obvious steps.
# Visualizations should include titles, axis labels, and legends where appropriate to make them self-explanatory. Finally, the notebook should conclude with a summary of findings, any conclusions drawn, and possible next steps. This narrative structure turns your notebook from a mere collection of code cells into a coherent story about your data analysis journey.
# </ol>
# </div>

# %% [markdown]
# # Libraries & Data

# %%
# Importing default Libraries
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import seaborn as sns
import warnings
import datetime 
import os 

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# Hi-resolution Plots and Matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# Set the maximum number of rows and columns to be displayed
warnings.filterwarnings('ignore')

# "magic commands" to enable autoreload of your imported packages
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Loading Data

# %%
# %pwd
# Out:
# '/Users/janduplessis/code/janduplessis883/project-streamlit_experiment/notebooks'

# %%
data = pd.read_parquet('../streamlit_exp/data/gpreviews_sa.parquet')
data.head(2)
# Out:
#       ode       Practice_Name  star_rating  \
# 0  Y01163  West Coker Surgery          5.0
# 1  Y01163  West Coker Surgery          1.0
#
#                                               title  \
# 0                                    Friendly staff
# 1  Uncaring, rude and disrespectful reception staff
#
#                                              comment   PCN      Region  \
# 0  Pharmacy and all staff extremely helpful.  No ...  None  South West
# 1  I have visited the reception about 7 times in ...  None  South West
#
#                 ICB  comment_len sentiment  sentiment_score       time
# 0  NHS Somerset ICB           22  positive         0.932635 2022-01-01
# 1  NHS Somerset ICB          143  negative         0.534633 2022-01-01

# %%
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#    index     ode       Practice_Name  star_rating  \
# 0      0  Y01163  West Coker Surgery          5.0
# 1      1  Y01163  West Coker Surgery          1.0
# 2      2  Y01163  West Coker Surgery          5.0
# 3      3  Y01163  West Coker Surgery          3.0
# 4      4  Y01163  West Coker Surgery          1.0
#
#                                               title  \
# 0                                    Friendly staff
# 1  Uncaring, rude and disrespectful reception staff
# 2                              personalised service
# 3                             Great reception staff
# 4                              Refused medical help
#
#                                              comment   PCN      Region  \
# 0  Pharmacy and all staff extremely helpful.  No ...  None  South West
# 1  I have visited the reception about 7 times in ...  None  South West
# 2  My family has been using this surgery since 20...  None  South West
# 3  I was astounded to read the reviews about the ...  None  South West
# 4  I recently visited England and whilst I was at...  None  South West
#
#                 ICB  comment_len sentiment  sentiment_score       time
# 0  NHS Somerset ICB           22  positive         0.932635 2022-01-01
# 1  NHS Somerset ICB          143  negative         0.534633 2022-01-01
# 2  NHS Somerset ICB           42  positive         0.953840 2022-01-01
# 3  NHS Somerset ICB           58  positive         0.448292 2022-02-01
# 4  NHS Somerset ICB          200   neutral         0.647720 2022-09-01

# %%
data.isna().sum()
# Out:
# ode                  0
# Practice_Name        0
# star_rating          0
# title                1
# comment              4
# PCN                192
# Region               0
# ICB                  0
# comment_len          0
# sentiment            0
# sentiment_score      0
# time                 0
# dtype: int64

# %% [markdown]
# # Exploratory Analysis

# %%
cat = pd.read_csv('../streamlit_exp/data/classify_batch_results.csv')
cat.head(10)
# Out:
#    id                          category
# 0   0      Overall Patient Satisfaction
# 1   1       Reception Staff Interaction
# 2   2  Follow-Up and Continuity of Care
# 3   3       Reception Staff Interaction
# 4   4                    Patient Safety
# 5   5                 Telephone Service
# 6   6      Overall Patient Satisfaction
# 7   7       Reception Staff Interaction
# 8   8  Follow-Up and Continuity of Care
# 9   9       Reception Staff Interaction

# %%
merged_df = pd.merge(data, cat, left_index=True, right_on='id')
merged_df.head(10)
# Out:
#        ode                     Practice_Name  star_rating  \
# 0   Y01163                West Coker Surgery          5.0
# 1   Y01163                West Coker Surgery          1.0
# 2   Y01163                West Coker Surgery          5.0
# 3   Y01163                West Coker Surgery          3.0
# 4   Y01163                West Coker Surgery          1.0
# 5   Y01163                West Coker Surgery          5.0
# 8   L82007  Medical Centre Camelford Dr Nash          1.0
# 10  J83033              Whalebridge Practice          1.0
# 11  J83033              Whalebridge Practice          3.0
# 12  J83033              Whalebridge Practice          2.0
#
#                                                title  \
# 0                                     Friendly staff
# 1   Uncaring, rude and disrespectful reception staff
# 2                               personalised service
# 3                              Great reception staff
# 4                               Refused medical help
# 5                                    Superb Practice
# 8                                           Shocking
# 10           Receptionist have made me move practice
# 11         Helpful staff, nightmare for appointments
# 12                                    Poor reception
#
#                                               comment   PCN      Region  \
# 0   Pharmacy and all staff extremely helpful.  No ...  None  South West
# 1   I have visited the reception about 7 times in ...  None  South West
# 2   My family has been using this surgery since 20...  None  South West
# 3   I was astounded to read the reviews about the ...  None  South West
# 4   I recently visited England and whilst I was at...  None  South West
# 5   Absolutely staggered to read some of the revie...  None  South West
# 8   They have no disabled parkingTold to move my c...  None  South West
# 10  The receptionists are rude here  with no peopl...  None  South West
# 11  When dealing with the staff on the detail  or ...  None  South West
# 12  Receptionist are dismissive  it's shocking how...  None  South West
#
#                                                   ICB  comment_len sentiment  \
# 0                                    NHS Somerset ICB           22  positive
# 1                                    NHS Somerset ICB          143  negative
# 2                                    NHS Somerset ICB           42  positive
# 3                                    NHS Somerset ICB           58  positive
# 4                                    NHS Somerset ICB          200   neutral
# 5                                    NHS Somerset ICB          228  positive
# 8            NHS Cornwall and The Isles Of Scilly ICB           29  negative
# 10  NHS Bath and North East Somerset, Swindon and ...          106  negative
# 11  NHS Bath and North East Somerset, Swindon and ...           72   neutral
# 12  NHS Bath and North East Somerset, Swindon and ...           70  negative
#
#     sentiment_score       time  id                          category
# 0          0.932635 2022-01-01   0      Overall Patient Satisfaction
# 1          0.534633 2022-01-01   1       Reception Staff Interaction
# 2          0.953840 2022-01-01   2  Follow-Up and Continuity of Care
# 3          0.448292 2022-02-01   3       Reception Staff Interaction
# 4          0.647720 2022-09-01   4                    Patient Safety
# 5          0.734920 2022-11-01   5                 Telephone Service
# 8          0.801713 2022-07-01   8  Follow-Up and Continuity of Care
# 10         0.892406 2022-02-01  10       Reception Staff Interaction
# 11         0.428441 2022-08-01  11       Reception Staff Interaction
# 12         0.897069 2023-03-01  12       Reception Staff Interaction

# %%
merged_df['category'].value_counts()
# Out:
# category
# Reception Staff Interaction               6937
# Patient-Doctor Communication              3791
# Telephone Service                         2986
# Follow-Up and Continuity of Care          2671
# Medical Staff Competence                  2325
# Overall Patient Satisfaction              1743
# Prescription and Medication Management     896
# Patient Empowerment and Support            884
# Appointment Accessibility                  841
# Vaccinations                               838
# Test Results                               754
# Doctor Consultations                       462
# Health Outcome Satisfaction                425
# Patient Safety                             226
# Weekend Service Availability               197
# Mental Health Support                      166
# Facilities and Cleanliness                 150
# Patient Privacy and Confidentiality        133
# Patient Participation Group                 91
# Blood Test Results & Imaging                82
# Referral Efficiency                         74
# Emergency Handling                          61
# Home Visits                                 49
# Waiting Room Comfort                        37
# Nursing Quality                             37
# Telehealth Services                         33
# Online Services & Digital Health            31
# Cancer Screening                            24
# Patient Education and Resources             18
# Cultural Sensitivity                        10
# Accessibility for Disabled Patients          7
# Reception Staff Interactionid                2
# Telephone Serviceid                          1
# Medical Staff Competenceid                   1
# Name: count, dtype: int64
